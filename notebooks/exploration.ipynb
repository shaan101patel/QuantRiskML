# %%
import sys
import os

# Add the src directory to the path
sys.path.append(os.path.abspath('../src'))

from data_loader import DataLoader
from ml_models import RiskPremiaModel
from pricing import OptionPricing, OptionParams

# %% [markdown]
# ## 1. Data Loading
# Load historical market data.

# %%
loader = DataLoader(data_dir="../data/raw")
# df = loader.load_market_data("SPY", "2020-01-01", "2023-01-01")
# df.head()

# %% [markdown]
# ## 2. Machine Learning Model
# Initialize and train a risk premia model.

# %%
model = RiskPremiaModel(model_type="random_forest")
# model.train(X_train, y_train)
# predictions = model.predict(X_test)

# %% [markdown]
# ## 3. Option Pricing
# Calculate option prices and Greeks.

# %%
params = OptionParams(S=100, K=100, T=1, r=0.05, sigma=0.2, option_type="call")
# price = OptionPricing.black_scholes_price(params)
# greeks = OptionPricing.calculate_greeks(params)
# print(f"Price: {price}")
# print(f"Greeks: {greeks}")
