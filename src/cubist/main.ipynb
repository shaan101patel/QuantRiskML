# %%
import pandas as pd
import numpy as np

# %%
#pull cubist model results from csv


df = pd.read_csv('cubist_model_results.csv')1
print(df.head())
#analyze results
mean_results = df.mean()
print("Mean Results:")
print(mean_results)
# Out:
# Hello, Cubist!
